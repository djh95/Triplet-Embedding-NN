# %%
import cv2
from pycocotools.coco import COCO

dataDir='..'
dataType='val2017'
annFile='{}/../coco/annotations/instances_{}.json'.format(dataDir,dataType)


# initialize COCO api for instance annotations
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.84s)
# creating index...
# index created!

# %%
coco.getCatIds()
image_id = coco.getImgIds()
image_id.sort()
print(image_id)
cv2.imread('%s/images/%s/%s'%("../../",dataType,img['file_name']))
cv2.imshow()
# Out:
# [139, 285, 632, 724, 776, 785, 802, 872, 885, 1000, 1268, 1296, 1353, 1425, 1490, 1503, 1532, 1584, 1675, 1761, 1818, 1993, 2006, 2149, 2153, 2157, 2261, 2299, 2431, 2473, 2532, 2587, 2592, 2685, 2923, 3156, 3255, 3501, 3553, 3661, 3845, 3934, 4134, 4395, 4495, 4765, 4795, 5001, 5037, 5060, 5193, 5477, 5503, 5529, 5586, 5600, 5992, 6012, 6040, 6213, 6460, 6471, 6614, 6723, 6763, 6771, 6818, 6894, 6954, 7088, 7108, 7278, 7281, 7386, 7511, 7574, 7784, 7795, 7816, 7818, 7888, 7977, 7991, 8021, 8211, 8277, 8532, 8629, 8690, 8762, 8844, 8899, 9378, 9400, 9448, 9483, 9590, 9769, 9772, 9891, 9914, 10092, 10363, 10583, 10707, 10764, 10977, 10995, 11051, 11122, 11149, 11197, 11511, 11615, 11699, 11760, 11813, 12062, 12120, 12280, 12576, 12639, 12667, 12670, 12748, 13004, 13177, 13201, 13291, 13348, 13546, 13597, 13659, 13729, 13774, 13923, 14007, 14038, 14226, 14380, 14439, 14473, 14831, 14888, 15079, 15254, 15272, 15278, 15335, 15338, 15440, 15497, 15517, 15597, 15660, 15746, 15751, 15956, 1
# ...

# %%
import numpy as np
np.random.randint(0,10)
coco.loadImgs(139)
# Out:
# [{'license': 2,
#   'file_name': '000000000139.jpg',
#   'coco_url': 'http://images.cocodataset.org/val2017/000000000139.jpg',
#   'height': 426,
#   'width': 640,
#   'date_captured': '2013-11-21 01:34:01',
#   'flickr_url': 'http://farm9.staticflickr.com/8035/8024364858_9c41dc1666_z.jpg',
#   'id': 139}]

# %%
catIds = coco.getCatIds(catNms=['person']);
print(catIds)
# Out:
# [1]

# %%
coco.getCatIds(

# %%
imgIds = coco.getImgIds(catIds=catIds );
print(imgIds)
# Out:
# [532481, 458755, 385029, 311303, 393226, 532493, 8211, 327701, 188439, 434204, 401446, 213033, 466986, 213035, 319534, 516143, 32817, 532530, 188465, 434230, 475191, 254016, 131138, 16451, 81988, 376900, 507975, 434247, 204871, 516173, 122962, 98392, 442456, 32861, 213086, 442463, 311392, 311394, 49259, 221291, 442480, 368752, 319607, 417911, 32887, 450686, 32901, 270474, 139, 180383, 82085, 385190, 524456, 90284, 32941, 188592, 229553, 278705, 213171, 336053, 549055, 114884, 508101, 65736, 303305, 344268, 532690, 360661, 16598, 73946, 114907, 426203, 278749, 516318, 229601, 295138, 467176, 319721, 352491, 33005, 458992, 475387, 393469, 57597, 426241, 540932, 106757, 65798, 180487, 213255, 147725, 418062, 147729, 377113, 229659, 147740, 426268, 434459, 205105, 565563, 278848, 368961, 352582, 57672, 74058, 123213, 33104, 336209, 180560, 483667, 8532, 270677, 262487, 491867, 475484, 393569, 549220, 336232, 74092, 467315, 131444, 434548, 532855, 442746, 541055, 426376, 336265, 303499, 3
# ...

# %%
img = coco.loadImgs([324158])[0]
print(img)
coco.getImgIds(imgIds = [324158])
# Out:
# {'license': 1, 'file_name': '000000324158.jpg', 'coco_url': 'http://images.cocodataset.org/val2017/000000324158.jpg', 'height': 334, 'width': 500, 'date_captured': '2013-11-19 23:54:06', 'flickr_url': 'http://farm1.staticflickr.com/169/417836491_5bf8762150_z.jpg', 'id': 324158}
# [324158]

# %%
cv2.imread('../../coco/images/%s/%s'%(dataType,img['file_name']))
# Out:
# array([[[240, 221, 206],
#         [225, 209, 192],
#         [251, 237, 219],
#         ...,
#         [238, 226, 222],
#         [189, 181, 182],
#         [ 62,  58,  57]],
#
#        [[255, 240, 217],
#         [247, 231, 208],
#         [221, 207, 184],
#         ...,
#         [245, 230, 228],
#         [190, 176, 180],
#         [ 13,   4,   7]],
#
#        [[250, 233, 206],
#         [255, 238, 211],
#         [255, 243, 217],
#         ...,
#         [237, 225, 225],
#         [ 93,  83,  89],
#         [ 21,  14,  19]],
#
#        ...,
#
#        [[ 98, 106, 113],
#         [108, 116, 123],
#         [128, 136, 143],
#         ...,
#         [103, 127, 151],
#         [111, 138, 164],
#         [ 64,  94, 119]],
#
#        [[115, 122, 131],
#         [126, 134, 141],
#         [118, 126, 133],
#         ...,
#         [ 80, 104, 128],
#         [ 78, 106, 130],
#         [ 95, 126, 151]],
#
#        [[118, 126, 133],
#         [115, 123, 130],
#         [ 99, 107, 114],
# ...

# %%
imgIds.sort()
dict(zip(imgIds, range(0,len(imgIds))))
# Out:
# {139: 0,
#  785: 1,
#  872: 2,
#  885: 3,
#  1000: 4,
#  1268: 5,
#  1296: 6,
#  1353: 7,
#  1490: 8,
#  1584: 9,
#  1761: 10,
#  2006: 11,
#  2153: 12,
#  2261: 13,
#  2299: 14,
#  2431: 15,
#  2473: 16,
#  2532: 17,
#  2685: 18,
#  3156: 19,
#  3255: 20,
#  3553: 21,
#  3934: 22,
#  4134: 23,
#  4395: 24,
#  4765: 25,
#  5001: 26,
#  5037: 27,
#  5060: 28,
#  5193: 29,
#  5529: 30,
#  5586: 31,
#  6040: 32,
#  6460: 33,
#  6471: 34,
#  6763: 35,
#  6771: 36,
#  6894: 37,
#  6954: 38,
#  7088: 39,
#  7278: 40,
#  7281: 41,
#  7511: 42,
#  7816: 43,
#  7977: 44,
#  8021: 45,
#  8211: 46,
#  8532: 47,
#  8690: 48,
#  8844: 49,
#  9378: 50,
#  9400: 51,
#  9448: 52,
#  9483: 53,
#  9590: 54,
#  9769: 55,
#  9772: 56,
#  9891: 57,
#  10707: 58,
#  10764: 59,
#  11051: 60,
#  11149: 61,
#  11197: 62,
#  11511: 63,
#  11699: 64,
#  12120: 65,
#  12280: 66,
#  12576: 67,
#  12639: 68,
#  12670: 69,
#  12748: 70,
#  13177: 71,
#  13201: 72,
#  13291: 73,
#  13348: 74,
#  13546: 75,
# ...

# %%
cats = self.coco.loadCats(self.coco.getCatIds())
        self.tag_list = [cat['name'] for cat in cats]
        image_ids = self.coco.getImgIds()
        self.image_ids_list = [cat['name'] for cat in cats]
I = io.imread('%s/images/%s/%s'%(dataDir,dataType,img['file_name']))
